# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
imdb_name_basics = pd.read_csv('data/imdb.name.basics.csv')
tmdb_movies = pd.read_csv('data/Tmdb.movies.csv')
tn_movie_budgets = pd.read_csv('data/tn.movie_budgets.csv')

imdb_title_principals = pd.read_csv('data/imdb.title.principals.csv')
rt_reviews = pd.read_csv('data/rt.reviews.tsv', delimiter='\t', encoding='unicode_escape')

imdb_title_akas = pd.read_csv('data/imdb.title.akas.csv')
imdb_title_crew = pd.read_csv('data/imdb.title.crew.csv')
pd.read_csv('data/rt.movie_info.tsv', delimiter='\t')

imdb_title_basics = pd.read_csv('data/imdb.title.basics.csv')
imdb_title_ratings = pd.read_csv('data/imdb.title.ratings.csv')
bom_movie_gross = pd.read_csv('data/bom.movie_gross.csv')

# %%
imdb_title_basics.set_index('tconst', inplace=True)
imdb_title_ratings.set_index('tconst', inplace=True)
imdb_title_crew.set_index('tconst', inplace=True)
imdb_title_principals.set_index('tconst', inplace=True)
imdb_frankenstein = imdb_title_basics.join(imdb_title_ratings, how='left')
imdb_frankenstein = imdb_frankenstein.join(imdb_title_crew, how='left')
imdb_frankenstein = imdb_frankenstein.join(imdb_title_principals, how='left')
imdb_frankenstein.reset_index(inplace=True)
imdb_frankenstein.set_index('nconst', inplace=True)
imdb_name_basics.set_index('nconst', inplace=True)
imdb_frankenstein = imdb_frankenstein.join(imdb_name_basics, how='left')

# %%
imdb_frankenstein.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1030876 entries, nm0000002 to nan
# Data columns (total 19 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   tconst              1030876 non-null  object
#  1   primary_title       1030876 non-null  object
#  2   original_title      1030855 non-null  object
#  3   start_year          1030876 non-null  int64
#  4   runtime_minutes     828893 non-null   float64
#  5   genres              1007380 non-null  object
#  6   averagerating       629926 non-null   float64
#  7   numvotes            629926 non-null   float64
#  8   directors           1014587 non-null  object
#  9   writers             861040 non-null   object
#  10  ordering            1028186 non-null  float64
#  11  category            1028186 non-null  object
#  12  job                 177684 non-null   object
#  13  characters          393360 non-null   object
# ...

# %%
imdb_frankenstein.describe()
# Out:
#          start_year  runtime_minutes  averagerating      numvotes  \
# count  1.030876e+06    828893.000000  629926.000000  6.299260e+05
# mean   2.014607e+03        90.390172       6.261943  4.108752e+03
# std    2.742710e+00       111.022517       1.452052  3.275891e+04
# min    2.010000e+03         1.000000       1.000000  5.000000e+00
# 25%    2.012000e+03        76.000000       5.400000  1.600000e+01
# 50%    2.015000e+03        90.000000       6.400000  6.500000e+01
# 75%    2.017000e+03       102.000000       7.300000  3.670000e+02
# max    2.115000e+03     51420.000000      10.000000  1.841066e+06
#
#            ordering     birth_year   death_year
# count  1.028186e+06  234048.000000  11843.00000
# mean   4.739847e+00    1967.742617   1995.25247
# std    2.747446e+00      22.099106     64.57055
# min    1.000000e+00       1.000000     17.00000
# 25%    2.000000e+00    1959.000000   2004.00000
# 50%    4.000000e+00    1971.000000   2014.00000
# ...

# %%
imdb_frankenstein.head
# Out:
# <bound method NDFrame.head of               tconst                                   primary_title  \
# nconst
# nm0000002  tt0858500                                Wide Blue Yonder
# nm0000002  tt1368858                                      The Forger
# nm0000002  tt1626811    Cameraman: The Life and Work of Jack Cardiff
# nm0000002  tt2053352           Diana Vreeland: The Eye Has to Travel
# nm0000003  tt1714820                                            1960
# ...              ...                                             ...
# NaN        tt9787912              Deoch an Dorais (Name Your Poison)
# NaN        tt9848124      Pinkfong 50 Best Hits: Baby Shark and More
# NaN        tt9853488                           Jade Hunters of China
# NaN        tt9877344                    The Elephant King Adventures
# NaN        tt9902734  Josh Groban Bridges from Madison Square Garden
#
#                                            original_title  start_year  \
# nconst
# ...

# %%
imdb_frankenstein.sort_values('numvotes')
# Out:
#               tconst                                      primary_title  \
# nconst
# nm6083628  tt7568474                   Hungarian Corridor - Warsaw 1944
# nm7775746  tt5915520                                       Strange Bird
# nm0145408  tt7929276  Partisan: Volksbühne am Rosa-Luxemburg-Platz 1...
# nm6691012  tt4872362                                      (313) Choices
# nm1652606  tt2072189                                Ordinary Wilderness
# ...              ...                                                ...
# NaN        tt9787912                 Deoch an Dorais (Name Your Poison)
# NaN        tt9848124         Pinkfong 50 Best Hits: Baby Shark and More
# NaN        tt9853488                              Jade Hunters of China
# NaN        tt9877344                       The Elephant King Adventures
# NaN        tt9902734     Josh Groban Bridges from Madison Square Garden
#
#                                               original_title  start_year  \
# nconst
# ...

# %%
genre_and_ratings = imdb_frankenstein[['original_title', 'genres', 'averagerating', 'numvotes']]

# %%
genre_and_ratings.drop_duplicates(inplace=True)
# Out:
# <ipython-input-9-841a4cc45101>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre_and_ratings.drop_duplicates(inplace=True)

# %%
genre_and_ratings['genres'].value_counts().to_frame()
# Out:
#                                 genres
# Documentary                      32022
# Drama                            21305
# Comedy                            9159
# Horror                            4357
# Comedy,Drama                      3516
# ...                                ...
# Comedy,Musical,War                   1
# Fantasy,War                          1
# Documentary,Reality-TV,Sport         1
# Animation,Documentary,Thriller       1
# Animation,History,Musical            1
#
# [1085 rows x 1 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-0eb9479c35f5> in <module>
# ----> 1 genre_and_ratings.groupby('genres')['averagerating'].value_counts(sort=ascending)
#       2
#
# NameError: name 'ascending' is not defined

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Documentary'].sort_values('averagerating', ascending=False)

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Documentary'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Documenatry Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Drama'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Drama Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Comedy'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Comedy Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Horror'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Horror Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Comedy,Drama'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Comedy,Drama Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Thriller'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Thriller Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Action'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Action Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Biography,Documentary'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Biography,Documentary Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Drama,Romance'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Drama,Romance Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Comedy,Drama,Romance'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Comedy,Drama,Romance Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Documentary,Drama'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.boxplot(x)
plt.title('Documentary,Drama Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Biography,Documentary'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Biography,Documentary Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Biography,Documentary'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Biography,Documentary Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Biography,Documentary'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Biography,Documentary Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Biography,Documentary'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Biography,Documentary Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Biography,Documentary'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Biography,Documentary Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Biography,Documentary'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Biography,Documentary Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Action,Adventure,Sci-Fi'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Action,Adventure,Sci-Fi Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Action,Thriller'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Action,Thriller Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Adventure,Drama,Sci-Fi'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Adventure,Drama,Sci-Fi Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Drama,Western'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Drama,Western Ratings')

# %%
documentaries = genre_and_ratings[genre_and_ratings['genres'] == 'Mystery,Thriller'].sort_values('averagerating', ascending=False)
documentaries
fig, axes = plt.subplots()
x= documentaries.value_counts('averagerating').index
y= documentaries.value_counts('averagerating').values
plt.scatter(x,y)
plt.title('Mystery,Thriller Ratings')
